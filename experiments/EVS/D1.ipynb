# %%
import os
import pickle
import numpy as np
import pandas as pd
import scipy.signal as signal
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

wesad_df = pd.read_csv('wesad_1hz_all_subjects.csv')
wesad_df
# Out:
#       subject  label       ecg       eda       temp      resp     acc_x  \
# 0          S2      0  0.034173  5.181544  30.247377 -1.218021  0.969442
# 1          S2      0 -0.096356  5.177953  30.247078 -0.468897  0.835454
# 2          S2      0 -0.094738  5.811486  30.235842  0.957831  0.860602
# 3          S2      0  0.062564  6.407475  30.247667 -0.300775  0.852237
# 4          S2      0  0.069053  6.234022  30.246643  0.902375  0.852700
# ...       ...    ...       ...       ...        ...       ...       ...
# 86863     S17      0  0.012518  7.185380  32.704660  6.548665  0.891498
# 86864     S17      0 -0.013845  7.182819  32.015800 -1.343822  0.897371
# 86865     S17      0 -0.010492  7.186100  32.800050 -5.516638  0.895874
# 86866     S17      0  0.003404  7.188020  32.136555 -5.366044  0.893502
# 86867     S17      0  0.005350  7.188192  32.010555 -5.261649  0.893262
#
#           acc_y     acc_z
# 0     -0.257653 -0.534531
# 1     -0.103890 -0.274835
# 2     -0.131935 -0.322404
# 3     -0.126013 -0.309526
# 4     -0.121735 -0.305027
# ...         ...       ...
# 86863 -0.032677 -0.172980
# 86864 -0.034048 -0.150464
# 86865 -0.040864 -0.153063
# 86866 -0.044590 -0.159368
# 86867 -0.044951 -0.160059
#
# [86868 rows x 9 columns]

# %%
# ----------------------------
# Prepare data for training
# ----------------------------
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

# Keep only 1, 2, and 4 (baseline, stress, meditation)
wesad_df = wesad_df[wesad_df["label"].isin([1, 2, 3])].reset_index(drop=True)

subject_ids = [f"S{i}" for i in range(2, 18)]  # S2–S17
test_subjects = ["S15", "S16", "S17"]  # held out for testing
train_subjects = [s for s in subject_ids if s not in test_subjects]


# Split by subject
train_df = wesad_df[wesad_df["subject"].isin(train_subjects)]
test_df = wesad_df[wesad_df["subject"].isin(test_subjects)]

print(f"Train subjects: {train_subjects}")
print(f"Test subjects: {test_subjects}")
print(f"Train shape: {train_df.shape}, Test shape: {test_df.shape}")

# Features
features = ["ecg", "eda", "temp", "resp", "acc_x", "acc_y", "acc_z"]

X_train = train_df[features].values
y_train = train_df["label"].values
X_test = test_df[features].values
y_test = test_df["label"].values

# ✅ Remap labels to 0, 1, 2
label_encoder = {1: 0, 2: 1, 3: 2}  # baseline=0, stress=1, meditation=2
y_train = np.vectorize(label_encoder.get)(y_train)
y_test = np.vectorize(label_encoder.get)(y_test)

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convert to small sequences for LSTM (e.g. 60s windows)
window = 60  # 60 timesteps = 1 minute
stride = 2 # 50% overlap

def make_sequences(X, y, window, stride):
    X_seq, y_seq = [], []
    for i in range(0, len(X) - window, stride):
        X_seq.append(X[i:i+window])
        # majority label in window
        vals, counts = np.unique(y[i:i+window], return_counts=True)
        y_seq.append(vals[np.argmax(counts)])
    return np.array(X_seq), np.array(y_seq)

X_train_seq, y_train_seq = make_sequences(X_train, y_train, window, stride)
X_test_seq, y_test_seq = make_sequences(X_test, y_test, window, stride)

print(f"Train seq: {X_train_seq.shape}, Test seq: {X_test_seq.shape}")

# One-hot encode labels
num_classes = len(np.unique(y_train_seq))
y_train_cat = to_categorical(y_train_seq, num_classes)
y_test_cat = to_categorical(y_test_seq, num_classes)

print(f"Number of classes: {num_classes} → {label_encoder}")
# Out:
# Train subjects: ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14']
# Test subjects: ['S15', 'S16', 'S17']
# Train shape: (24178, 9), Test shape: (6132, 9)
# Train seq: (12059, 60, 7), Test seq: (3036, 60, 7)
# Number of classes: 3 → {1: 0, 2: 1, 3: 2}

# %%
# %%
# ----------------------------
# Build CNN + LSTM classifier
# ----------------------------
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, LSTM, Dense,
    Dropout, BatchNormalization, Flatten
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])

model = Sequential([
    Conv1D(64, kernel_size=5, activation='relu', padding='same', input_shape=input_shape),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    Conv1D(128, kernel_size=3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),

    LSTM(128, return_sequences=True),
    Dropout(0.3),

    LSTM(64, return_sequences=False),
    Dropout(0.3),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\chand\anaconda3\envs\AllPackages\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\chand\anaconda3\envs\AllPackages\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 60, 64)            2304
#
#  batch_normalization (Batch  (None, 60, 64)            256
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 30, 64)            0
#  D)
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  conv1d_1 (Conv1D)           (None, 30, 128)           24704
#
#  batch_normalization_1 (Bat  (None, 30, 128)           512
#  chNormalization)
#
#  max_pooling1d_1 (MaxPoolin  (None, 15, 128)           0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 15, 128)           0
#
#  lstm (LSTM)                 (None, 15, 128)           131584
#
#  dropout_2 (Dropout)         (None, 15, 128)           0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 213379 (833.51 KB)
# Trainable params: 212867 (831.51 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
# ----------------------------
# Train model
# ----------------------------
early_stop = EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True, verbose=1)
checkpoint = ModelCheckpoint("best_wesad_classifier.keras", monitor="val_accuracy", save_best_only=True, verbose=1)
lr_reduce = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10, min_lr=1e-6, verbose=1)

history = model.fit(
    X_train_seq, y_train_cat,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=[early_stop, checkpoint, lr_reduce],
    verbose=1
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\chand\anaconda3\envs\AllPackages\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\chand\anaconda3\envs\AllPackages\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 150/151 [============================>.] - ETA: 0s - loss: 0.6105 - accuracy: 0.7648
# Epoch 1: val_accuracy improved from -inf to 0.59619, saving model to best_wesad_classifier.keras
# 151/151 [==============================] - 14s 54ms/step - loss: 0.6094 - accuracy: 0.7652 - val_loss: 0.9489 - val_accuracy: 0.5962 - lr: 5.0000e-04
# Epoch 2/50
# 150/151 [============================>.] - ETA: 0s - loss: 0.2614 - accuracy: 0.9203
# Epoch 2: val_accuracy improved from 0.59619 to 0.73922, saving model to best_wesad_classifier.keras
# 151/151 [==============================] - 6s 39ms/step - loss: 0.2610 - accuracy: 0.9204 - val_loss: 0.8358 - val_accuracy: 0.7392 - lr: 5.0000e-04
# Epoch 3/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9443
# Epoch 3: val_accuracy did not improve from 0.73922
# 151/151 [==============================] - 6s 41ms/step - loss: 0.1750 - accuracy: 0.9443 - val_loss: 1.0366 - val_accuracy: 0.7214 - lr: 5.0000e-04
# Epoch 4/50
# 150/151 [============================>.] - ETA: 0s - loss: 0.1301 - accuracy: 0.9622
# Epoch 4: val_accuracy did not improve from 0.73922
# 151/151 [==============================] - 7s 47ms/step - loss: 0.1303 - accuracy: 0.9622 - val_loss: 1.2200 - val_accuracy: 0.7189 - lr: 5.0000e-04
# Epoch 5/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9656
# Epoch 5: val_accuracy improved from 0.73922 to 0.76700, saving model to best_wesad_classifier.keras
# 151/151 [==============================] - 7s 46ms/step - loss: 0.1118 - accuracy: 0.9656 - val_loss: 1.1523 - val_accuracy: 0.7670 - lr: 5.0000e-04
# Epoch 6/50
# 151/151 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9690
# Epoch 6: val_accuracy did not improve from 0.76700
# 151/151 [==============================] - 7s 49ms/step - loss: 0.1001 - accuracy: 0.9690 - val_loss: 1.1808 - val_accuracy: 0.7413 - lr: 5.0000e-04
# Epoch 7/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9752
# Epoch 7: val_accuracy improved from 0.76700 to 0.79104, saving model to best_wesad_classifier.keras
# 151/151 [==============================] - 7s 45ms/step - loss: 0.0837 - accuracy: 0.9752 - val_loss: 0.9139 - val_accuracy: 0.7910 - lr: 5.0000e-04
# Epoch 8/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9795
# Epoch 8: val_accuracy did not improve from 0.79104
# 151/151 [==============================] - 6s 42ms/step - loss: 0.0678 - accuracy: 0.9795 - val_loss: 1.0835 - val_accuracy: 0.7533 - lr: 5.0000e-04
# Epoch 9/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0671 - accuracy: 0.9804
# Epoch 9: val_accuracy did not improve from 0.79104
# 151/151 [==============================] - 8s 53ms/step - loss: 0.0671 - accuracy: 0.9804 - val_loss: 1.4718 - val_accuracy: 0.7313 - lr: 5.0000e-04
# Epoch 10/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9799
# Epoch 10: val_accuracy did not improve from 0.79104
# 151/151 [==============================] - 7s 45ms/step - loss: 0.0686 - accuracy: 0.9799 - val_loss: 1.1946 - val_accuracy: 0.7670 - lr: 5.0000e-04
# Epoch 11/50
# 150/151 [============================>.] - ETA: 0s - loss: 0.0545 - accuracy: 0.9834
# Epoch 11: val_accuracy improved from 0.79104 to 0.81219, saving model to best_wesad_classifier.keras
# 151/151 [==============================] - 7s 45ms/step - loss: 0.0551 - accuracy: 0.9833 - val_loss: 0.9326 - val_accuracy: 0.8122 - lr: 5.0000e-04
# Epoch 12/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0698 - accuracy: 0.9770
# Epoch 12: val_accuracy did not improve from 0.81219
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 151/151 [==============================] - 7s 45ms/step - loss: 0.0698 - accuracy: 0.9770 - val_loss: 1.3088 - val_accuracy: 0.7322 - lr: 5.0000e-04
# Epoch 13/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9847
# Epoch 13: val_accuracy did not improve from 0.81219
# 151/151 [==============================] - 6s 39ms/step - loss: 0.0466 - accuracy: 0.9847 - val_loss: 1.1920 - val_accuracy: 0.7425 - lr: 2.5000e-04
# Epoch 14/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9864
# Epoch 14: val_accuracy did not improve from 0.81219
# 151/151 [==============================] - 7s 44ms/step - loss: 0.0432 - accuracy: 0.9864 - val_loss: 1.0865 - val_accuracy: 0.7591 - lr: 2.5000e-04
# Epoch 15/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9866
# Epoch 15: val_accuracy did not improve from 0.81219
# 151/151 [==============================] - 6s 41ms/step - loss: 0.0438 - accuracy: 0.9866 - val_loss: 1.0141 - val_accuracy: 0.7782 - lr: 2.5000e-04
# Epoch 16/50
# 151/151 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9888
# Epoch 16: val_accuracy did not improve from 0.81219
# 151/151 [==============================] - 7s 47ms/step - loss: 0.0357 - accuracy: 0.9888 - val_loss: 1.1640 - val_accuracy: 0.7587 - lr: 2.5000e-04
# Epoch 17/50
# 150/151 [============================>.] - ETA: 0s - loss: 0.0326 - accuracy: 0.9883Restoring model weights from the end of the best epoch: 2.
#
# Epoch 17: val_accuracy did not improve from 0.81219
# 151/151 [==============================] - 8s 50ms/step - loss: 0.0325 - accuracy: 0.9884 - val_loss: 1.1008 - val_accuracy: 0.7769 - lr: 2.5000e-04
# Epoch 17: early stopping

# %%
# %%
# ----------------------------
# Evaluate model
# ----------------------------
best_model = tf.keras.models.load_model("best_wesad_classifier.keras")
loss, acc = best_model.evaluate(X_test_seq, y_test_cat, verbose=0)
print(f"\nTest Accuracy: {acc*100:.2f}%")

# Predictions
y_pred = np.argmax(best_model.predict(X_test_seq), axis=1)

from sklearn.metrics import classification_report, confusion_matrix
print("\nClassification Report:")
target_names = ["baseline", "stress", "meditation"]
print(classification_report(y_test_seq, y_pred, target_names=target_names))
# Out:
# Test Accuracy: 64.16%
# 95/95 [==============================] - 2s 13ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     baseline       0.76      0.73      0.74      1849
#       stress       0.50      0.56      0.53       481
#   meditation       0.46      0.46      0.46       706
#
#     accuracy                           0.64      3036
#    macro avg       0.57      0.58      0.58      3036
# weighted avg       0.65      0.64      0.64      3036

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test_seq, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names,
            yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix - WESAD Classifier (3 Classes)")
plt.tight_layout()
plt.show()
